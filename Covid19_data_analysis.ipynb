# %% [markdown]
# <a href="https://colab.research.google.com/github/sshashank99/covid_analysis/blob/master/Covid19_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corona_dataset = pd.read_csv('covid19_Confirmed_dataset.csv')
corona_dataset.head(10)
# Out:
#                  Province/State       Country/Region  ...  4/29/20  4/30/20
# 0                           NaN          Afghanistan  ...     1939     2171
# 1                           NaN              Albania  ...      766      773
# 2                           NaN              Algeria  ...     3848     4006
# 3                           NaN              Andorra  ...      743      745
# 4                           NaN               Angola  ...       27       27
# 5                           NaN  Antigua and Barbuda  ...       24       24
# 6                           NaN            Argentina  ...     4285     4428
# 7                           NaN              Armenia  ...     1932     2066
# 8  Australian Capital Territory            Australia  ...      106      106
# 9               New South Wales            Australia  ...     3016     3025
#
# [10 rows x 104 columns]

# %%
corona_dataset.shape
# Out:
# (266, 104)

# %%
corona_dataset.drop(['Lat','Long'],axis=1,inplace=True)

# %%
corona_dataset.head(10)
# Out:
#                  Province/State       Country/Region  ...  4/29/20  4/30/20
# 0                           NaN          Afghanistan  ...     1939     2171
# 1                           NaN              Albania  ...      766      773
# 2                           NaN              Algeria  ...     3848     4006
# 3                           NaN              Andorra  ...      743      745
# 4                           NaN               Angola  ...       27       27
# 5                           NaN  Antigua and Barbuda  ...       24       24
# 6                           NaN            Argentina  ...     4285     4428
# 7                           NaN              Armenia  ...     1932     2066
# 8  Australian Capital Territory            Australia  ...      106      106
# 9               New South Wales            Australia  ...     3016     3025
#
# [10 rows x 102 columns]

# %%
corona_dataset_aggregated = corona_dataset.groupby("Country/Region").sum()
corona_dataset_aggregated.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  ...  4/28/20  4/29/20  4/30/20
# Country/Region                                  ...
# Afghanistan                0        0        0  ...     1828     1939     2171
# Albania                    0        0        0  ...      750      766      773
# Algeria                    0        0        0  ...     3649     3848     4006
# Andorra                    0        0        0  ...      743      743      745
# Angola                     0        0        0  ...       27       27       27
# Antigua and Barbuda        0        0        0  ...       24       24       24
# Argentina                  0        0        0  ...     4127     4285     4428
# Armenia                    0        0        0  ...     1867     1932     2066
# Australia                  0        0        0  ...     6744     6752     6766
# Austria                    0        0        0  ...    15357    15402    15452
#
# [10 rows x 100 columns]

# %%
corona_dataset_aggregated.shape
# Out:
# (187, 100)

# %%
corona_dataset_aggregated.loc['Italy'].plot()
corona_dataset_aggregated.loc['China'].plot()
corona_dataset_aggregated.loc['India'].plot()
plt.legend()

# %%
corona_dataset_aggregated.loc['India'].plot()

# %%
corona_dataset_aggregated.loc['India'].diff().plot()

# %%
corona_dataset_aggregated.loc['India'].diff().max()
# Out:
# 1893.0

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for country in countries :
    max_infection_rates.append(corona_dataset_aggregated.loc[country].diff().max())
corona_dataset_aggregated['max infection rate'] = max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  4/29/20  4/30/20  max infection rate
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1939     2171               232.0
# Albania               0        0        0  ...      766      773                34.0
# Algeria               0        0        0  ...     3848     4006               199.0
# Andorra               0        0        0  ...      743      745                43.0
# Angola                0        0        0  ...       27       27                 5.0
#
# [5 rows x 101 columns]

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated['max infection rate'])
corona_data.head(10)
# Out:
#                      max infection rate
# Country/Region
# Afghanistan                       232.0
# Albania                            34.0
# Algeria                           199.0
# Andorra                            43.0
# Angola                              5.0
# Antigua and Barbuda                 6.0
# Argentina                         291.0
# Armenia                           134.0
# Australia                         497.0
# Austria                          1321.0

# %%
world_happiness_report = pd.read_csv("worldwide_happiness_report.csv")
world_happiness_report.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %%
columns_to_dropped = ['Overall rank','Score','Generosity','Perceptions of corruption']
world_happiness_report.drop(columns_to_dropped,axis=1 , inplace=True)
world_happiness_report.head()
# Out:
#   Country or region  ...  Freedom to make life choices
# 0           Finland  ...                         0.596
# 1           Denmark  ...                         0.592
# 2            Norway  ...                         0.603
# 3           Iceland  ...                         0.591
# 4       Netherlands  ...                         0.557
#
# [5 rows x 5 columns]

# %%
world_happiness_report.set_index(['Country or region'],inplace=True)
world_happiness_report.head()
# Out:
#                    GDP per capita  ...  Freedom to make life choices
# Country or region                  ...
# Finland                     1.340  ...                         0.596
# Denmark                     1.383  ...                         0.592
# Norway                      1.488  ...                         0.603
# Iceland                     1.380  ...                         0.591
# Netherlands                 1.396  ...                         0.557
#
# [5 rows x 4 columns]

# %%
corona_data.head()
# Out:
#                 max infection rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %%
world_happiness_report.head()
# Out:
#                    GDP per capita  ...  Freedom to make life choices
# Country or region                  ...
# Finland                     1.340  ...                         0.596
# Denmark                     1.383  ...                         0.592
# Norway                      1.488  ...                         0.603
# Iceland                     1.380  ...                         0.591
# Netherlands                 1.396  ...                         0.557
#
# [5 rows x 4 columns]

# %%
data = world_happiness_report.join(corona_data).copy()
data.head()
# Out:
#                    GDP per capita  ...  max infection rate
# Country or region                  ...
# Finland                     1.340  ...               267.0
# Denmark                     1.383  ...               391.0
# Norway                      1.488  ...               386.0
# Iceland                     1.380  ...                99.0
# Netherlands                 1.396  ...              1346.0
#
# [5 rows x 5 columns]

# %%
data.corr()
# Out:
#                               GDP per capita  ...  max infection rate
# GDP per capita                      1.000000  ...            0.250118
# Social support                      0.754906  ...            0.191958
# Healthy life expectancy             0.835462  ...            0.289263
# Freedom to make life choices        0.379079  ...            0.078196
# max infection rate                  0.250118  ...            1.000000
#
# [5 rows x 5 columns]

# %%
x = data['Healthy life expectancy']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %%
x = data['Social support']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %%
corona_dataset_deaths = pd.read_csv('covid19_deaths_dataset.csv')
corona_dataset_deaths.head(10)
# Out:
#                  Province/State       Country/Region  ...  4/29/20  4/30/20
# 0                           NaN          Afghanistan  ...       60       64
# 1                           NaN              Albania  ...       30       31
# 2                           NaN              Algeria  ...      444      450
# 3                           NaN              Andorra  ...       42       42
# 4                           NaN               Angola  ...        2        2
# 5                           NaN  Antigua and Barbuda  ...        3        3
# 6                           NaN            Argentina  ...      214      218
# 7                           NaN              Armenia  ...       30       32
# 8  Australian Capital Territory            Australia  ...        3        3
# 9               New South Wales            Australia  ...       40       41
#
# [10 rows x 104 columns]

# %%
corona_dataset_deaths.drop(['Lat','Long'],axis=1,inplace=True)

# %%
corona_dataset_deaths.head(10)
# Out:
#                  Province/State       Country/Region  ...  4/29/20  4/30/20
# 0                           NaN          Afghanistan  ...       60       64
# 1                           NaN              Albania  ...       30       31
# 2                           NaN              Algeria  ...      444      450
# 3                           NaN              Andorra  ...       42       42
# 4                           NaN               Angola  ...        2        2
# 5                           NaN  Antigua and Barbuda  ...        3        3
# 6                           NaN            Argentina  ...      214      218
# 7                           NaN              Armenia  ...       30       32
# 8  Australian Capital Territory            Australia  ...        3        3
# 9               New South Wales            Australia  ...       40       41
#
# [10 rows x 102 columns]

# %%
corona_dataset_aggregated_deaths = corona_dataset_deaths.groupby("Country/Region").sum()
corona_dataset_aggregated_deaths.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  ...  4/28/20  4/29/20  4/30/20
# Country/Region                                  ...
# Afghanistan                0        0        0  ...       58       60       64
# Albania                    0        0        0  ...       30       30       31
# Algeria                    0        0        0  ...      437      444      450
# Andorra                    0        0        0  ...       41       42       42
# Angola                     0        0        0  ...        2        2        2
# Antigua and Barbuda        0        0        0  ...        3        3        3
# Argentina                  0        0        0  ...      207      214      218
# Armenia                    0        0        0  ...       30       30       32
# Australia                  0        0        0  ...       89       91       93
# Austria                    0        0        0  ...      569      580      584
#
# [10 rows x 100 columns]

# %%
corona_dataset_aggregated_deaths.loc['Italy'].plot()
corona_dataset_aggregated_deaths.loc['China'].plot()
corona_dataset_aggregated_deaths.loc['India'].plot()
plt.legend()

# %%
corona_dataset_aggregated_deaths.loc['India'].diff().plot()

# %%
corona_dataset_aggregated_deaths.loc['India'].diff().max()
# Out:
# 75.0

# %%
countries = list(corona_dataset_aggregated.index)
max_death_rates = []
for country in countries :
    max_death_rates.append(corona_dataset_aggregated_deaths.loc[country].diff().max())
corona_dataset_aggregated_deaths['max death rate'] = max_death_rates

# %%
corona_dataset_aggregated_deaths.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  4/29/20  4/30/20  max death rate
# Country/Region                             ...
# Afghanistan           0        0        0  ...       60       64             7.0
# Albania               0        0        0  ...       30       31             4.0
# Algeria               0        0        0  ...      444      450            30.0
# Andorra               0        0        0  ...       42       42             4.0
# Angola                0        0        0  ...        2        2             2.0
#
# [5 rows x 101 columns]

# %%
corona_data_deaths = pd.DataFrame(corona_dataset_aggregated_deaths['max death rate'])
corona_data_deaths.head(10)
# Out:
#                      max death rate
# Country/Region
# Afghanistan                     7.0
# Albania                         4.0
# Algeria                        30.0
# Andorra                         4.0
# Angola                          2.0
# Antigua and Barbuda             1.0
# Argentina                      13.0
# Armenia                         3.0
# Australia                       8.0
# Austria                        30.0

# %%
corona_data.head(10)
# Out:
#                      max infection rate
# Country/Region
# Afghanistan                       232.0
# Albania                            34.0
# Algeria                           199.0
# Andorra                            43.0
# Angola                              5.0
# Antigua and Barbuda                 6.0
# Argentina                         291.0
# Armenia                           134.0
# Australia                         497.0
# Austria                          1321.0

# %%
data2 = corona_data.join(corona_data_deaths).copy()
data2.head(10)
# Out:
#                      max infection rate  max death rate
# Country/Region
# Afghanistan                       232.0             7.0
# Albania                            34.0             4.0
# Algeria                           199.0            30.0
# Andorra                            43.0             4.0
# Angola                              5.0             2.0
# Antigua and Barbuda                 6.0             1.0
# Argentina                         291.0            13.0
# Armenia                           134.0             3.0
# Australia                         497.0             8.0
# Austria                          1321.0            30.0

# %%
data3 = world_happiness_report.join(data2).copy()
data3.head()
# Out:
#                    GDP per capita  ...  max death rate
# Country or region                  ...
# Finland                     1.340  ...            43.0
# Denmark                     1.383  ...            22.0
# Norway                      1.488  ...            16.0
# Iceland                     1.380  ...             5.0
# Netherlands                 1.396  ...           234.0
#
# [5 rows x 6 columns]
